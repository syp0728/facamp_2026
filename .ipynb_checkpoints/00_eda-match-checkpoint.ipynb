# %% [markdown]
# **_Copyright Notice_**
#
# This notebook is available for educational purposes. You may not use or distribute this notebook for commercial purposes. You may make copies of this notebook and use or distribute it for educational purposes as long as you cite the author as the source of the notebook.
#
# Jaeyoung Chun | School of Applied Artificial Intelligence | Handong Global University

# %% [markdown]
# # EDA on International Match Data

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.2'

# %% [markdown]
# ## Load International Match Data

# %%
match = pd.read_csv('../data/results.csv')

# %%
match
# Out:
#              date home_team   away_team  home_score  away_score  \
# 0      1872-11-30  Scotland     England         0.0         0.0
# 1      1873-03-08   England    Scotland         4.0         2.0
# 2      1874-03-07  Scotland     England         2.0         1.0
# 3      1875-03-06   England    Scotland         2.0         2.0
# 4      1876-03-04  Scotland     England         3.0         0.0
# ...           ...       ...         ...         ...         ...
# 49440  2026-06-27    Jordan   Argentina         NaN         NaN
# 49441  2026-06-27  Colombia    Portugal         NaN         NaN
# 49442  2026-06-27  DR Congo  Uzbekistan         NaN         NaN
# 49443  2026-06-27    Panama     England         NaN         NaN
# 49444  2026-06-27   Croatia       Ghana         NaN         NaN
#
#            tournament             city        country  neutral
# 0            Friendly          Glasgow       Scotland    False
# 1            Friendly           London        England    False
# ...

# %% [markdown]
# ## Tournament Types

# %%
match.tournament.unique()
# Out:
# array(['Friendly', 'British Home Championship', 'Évence Coppée Trophy',
#        'Muratti Vase', 'Copa Lipton', 'Copa Newton',
#        'Copa Premio Honor Argentino', 'Olympic Games',
#        'Copa Premio Honor Uruguayo', 'Far Eastern Championship Games',
#        'Copa Roca', 'Copa América', 'Inter-Allied Games', 'Peace Cup',
#        'Open International Championship', 'Soccer Ashes',
#        'Copa Chevallier Boutell', 'Nordic Championship',
#        'Central European International Cup', 'Baltic Cup', 'Balkan Cup',
#        'Central American and Caribbean Games', 'FIFA World Cup',
#        'Copa Rio Branco', 'FIFA World Cup qualification',
#        'Bolivarian Games', 'CCCF Championship', 'NAFC Championship',
#        'Copa Oswaldo Cruz', 'Asian Games', 'Pan American Championship',
#        'Copa del Pacífico', "Copa Bernardo O'Higgins",
#        'AFC Asian Cup qualification', 'Atlantic Cup', 'AFC Asian Cup',
#        'African Cup of Nations', 'Copa Paz del Chaco',
# ...

# %% [markdown]
# ## Convert to DateTime

# %%
match["date"] = pd.to_datetime(match["date"])

# %%
match.dtypes
# Out:
# date          datetime64[ns]
# home_team             object
# away_team             object
# home_score           float64
# away_score           float64
# tournament            object
# city                  object
# country               object
# neutral                 bool
# dtype: object

# %% [markdown]
# ## Keep Only 2022

# %%
match_2022 = match[ match["date"].dt.year == 2022 ].copy()

# %%
match_2022
# Out:
#             date             home_team     away_team  home_score  away_score  \
# 44837 2022-01-01              Thailand     Indonesia         2.0         2.0
# 44838 2022-01-02                 Gabon  Burkina Faso         0.0         3.0
# 44839 2022-01-02                 Sudan      Zimbabwe         0.0         0.0
# 44840 2022-01-03                Rwanda        Guinea         3.0         0.0
# 44841 2022-01-04            Mauritania         Gabon         1.0         1.0
# ...          ...                   ...           ...         ...         ...
# 45801 2022-12-30                  Iraq        Kuwait         1.0         0.0
# 45802 2022-12-30                  Oman         Syria         1.0         0.0
# 45803 2022-12-30  United Arab Emirates       Lebanon         1.0         0.0
# 45804 2022-12-30               Myanmar          Laos         2.0         2.0
# 45805 2022-12-30             Singapore       Vietnam         0.0         0.0
#
# ...

# %% [markdown]
# ## Keep Only South Korea

# %%
match_2022_kor = match_2022[ match_2022.home_team == "South Korea" ].copy()

# %%
match_2022_kor
# Out:
#             date    home_team   away_team  home_score  away_score  \
# 44863 2022-01-15  South Korea     Iceland         5.0         1.0
# 44881 2022-01-20  South Korea     Moldova         4.0         0.0
# 44978 2022-03-24  South Korea        Iran         2.0         0.0
# 45185 2022-06-02  South Korea      Brazil         1.0         5.0
# 45266 2022-06-06  South Korea       Chile         2.0         0.0
# 45344 2022-06-10  South Korea    Paraguay         2.0         2.0
# 45439 2022-06-14  South Korea       Egypt         4.0         1.0
# 45469 2022-07-24  South Korea   Hong Kong         3.0         0.0
# 45512 2022-09-23  South Korea  Costa Rica         2.0         2.0
# 45592 2022-09-27  South Korea    Cameroon         1.0         0.0
# 45633 2022-11-11  South Korea     Iceland         1.0         0.0
# 45746 2022-11-28  South Korea       Ghana         2.0         3.0
# 45763 2022-12-02  South Korea    Portugal         2.0         1.0
#
# ...

# %% [markdown]
# What is South Korea's FIFA ranking on 2022-09-27 (the date when the match with Cameroon was held)?
