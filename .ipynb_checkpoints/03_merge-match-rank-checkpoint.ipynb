# %% [markdown]
# **_Copyright Notice_**
#
# This notebook is available for educational purposes. You may not use or distribute this notebook for commercial purposes. You may make copies of this notebook and use or distribute it for educational purposes as long as you cite the author as the source of the notebook.
#
# Jaeyoung Chun | School of Applied Artificial Intelligence | Handong Global University

# %% [markdown]
# # Merging International Match and FIFA Ranking Data

# %%
import pandas as pd

# %% [markdown]
# ## Load FIFA Ranking Data

# %% [markdown]
# This is the preprocessed data.

# %%
df_rank = pd.read_parquet("./intermediate/rank.parquet")

# %%
df_rank
# Out:
#             rank country_full country_abrv  total_points  previous_points  \
# rank_date
# 2018-08-16   145  Afghanistan          AFG       1068.00          1068.00
# 2018-08-17   145  Afghanistan          AFG       1068.00          1068.00
# 2018-08-18   145  Afghanistan          AFG       1068.00          1068.00
# 2018-08-19   145  Afghanistan          AFG       1068.00          1068.00
# 2018-08-20   145  Afghanistan          AFG       1068.00          1068.00
# ...          ...          ...          ...           ...              ...
# 2022-10-02   123     Zimbabwe          ZIM       1138.56          1138.56
# 2022-10-03   123     Zimbabwe          ZIM       1138.56          1138.56
# 2022-10-04   123     Zimbabwe          ZIM       1138.56          1138.56
# 2022-10-05   123     Zimbabwe          ZIM       1138.56          1138.56
# 2022-10-06   125     Zimbabwe          ZIM       1138.56          1138.56
#
#             rank_change confederation
# rank_date
# ...

# %% [markdown]
# ## Remove Unnecessary Columns

# %%
df_rank.drop(columns=["country_abrv", "previous_points", "confederation"], inplace=True)

# %%
df_rank
# Out:
#             rank country_full  total_points  rank_change
# rank_date
# 2018-08-16   145  Afghanistan       1068.00            0
# 2018-08-17   145  Afghanistan       1068.00            0
# 2018-08-18   145  Afghanistan       1068.00            0
# 2018-08-19   145  Afghanistan       1068.00            0
# 2018-08-20   145  Afghanistan       1068.00            0
# ...          ...          ...           ...          ...
# 2022-10-02   123     Zimbabwe       1138.56            0
# 2022-10-03   123     Zimbabwe       1138.56            0
# 2022-10-04   123     Zimbabwe       1138.56            0
# 2022-10-05   123     Zimbabwe       1138.56            0
# 2022-10-06   125     Zimbabwe       1138.56            2
#
# [318899 rows x 4 columns]

# %% [markdown]
# ## Load International Match Data

# %%
df_match = pd.read_csv('../data/results.csv')

# %% [markdown]
# ## Convert to DateTime

# %%
df_match['date'] = pd.to_datetime(df_match['date'])

# %%
df_match
# Out:
#             date home_team   away_team  home_score  away_score  \
# 0     1872-11-30  Scotland     England         0.0         0.0
# 1     1873-03-08   England    Scotland         4.0         2.0
# 2     1874-03-07  Scotland     England         2.0         1.0
# 3     1875-03-06   England    Scotland         2.0         2.0
# 4     1876-03-04  Scotland     England         3.0         0.0
# ...          ...       ...         ...         ...         ...
# 49440 2026-06-27    Jordan   Argentina         NaN         NaN
# 49441 2026-06-27  Colombia    Portugal         NaN         NaN
# 49442 2026-06-27  DR Congo  Uzbekistan         NaN         NaN
# 49443 2026-06-27    Panama     England         NaN         NaN
# 49444 2026-06-27   Croatia       Ghana         NaN         NaN
#
#            tournament             city        country  neutral
# 0            Friendly          Glasgow       Scotland    False
# 1            Friendly           London        England    False
# ...

# %% [markdown]
# ## Merge Match and Ranking

# %% [markdown]
# ### Merge Home Team

# %%
df_merge_home = pd.merge(
    df_match,
    df_rank,
    left_on=["date", "home_team"],
    right_on=["rank_date", "country_full"],
    how="inner"
)

# %%
df_merge_home
# Out:
#            date  home_team             away_team  home_score  away_score  \
# 0    2018-08-18    Andorra  United Arab Emirates         0.0         0.0
# 1    2018-08-18    Grenada               Jamaica         1.0         5.0
# 2    2018-08-18  Guatemala                  Cuba         1.0         0.0
# 3    2018-08-20   Barbados               Jamaica         2.0         2.0
# 4    2018-08-25   Anguilla          Saint Martin         1.0         2.0
# ...         ...        ...                   ...         ...         ...
# 3610 2022-09-27     Norway                Serbia         0.0         2.0
# 3611 2022-09-27     Sweden              Slovenia         1.0         1.0
# 3612 2022-09-27     Kosovo                Cyprus         5.0         1.0
# 3613 2022-09-27     Greece      Northern Ireland         3.0         1.0
# 3614 2022-09-30       Fiji       Solomon Islands         1.0         0.0
#
#                     tournament            city    country  neutral  rank  \
# ...

# %% [markdown]
# ### Merge Away Team

# %%
df_merge_home_away = pd.merge(
    df_merge_home,
    df_rank,
    left_on=["date", "away_team"],
    right_on=["rank_date", "country_full"],
    suffixes=["_home", "_away"],
    how="inner"
)

# %%
df_merge_home_away
# Out:
#            date  home_team             away_team  home_score  away_score  \
# 0    2018-08-18    Andorra  United Arab Emirates         0.0         0.0
# 1    2018-08-18    Grenada               Jamaica         1.0         5.0
# 2    2018-08-18  Guatemala                  Cuba         1.0         0.0
# 3    2018-08-20   Barbados               Jamaica         2.0         2.0
# 4    2018-08-26   Barbados                  Cuba         0.0         0.0
# ...         ...        ...                   ...         ...         ...
# 3402 2022-09-27     Norway                Serbia         0.0         2.0
# 3403 2022-09-27     Sweden              Slovenia         1.0         1.0
# 3404 2022-09-27     Kosovo                Cyprus         5.0         1.0
# 3405 2022-09-27     Greece      Northern Ireland         3.0         1.0
# 3406 2022-09-30       Fiji       Solomon Islands         1.0         0.0
#
#                     tournament            city    country  neutral  rank_home  \
# ...

# %% [markdown]
# ## Drop Duplicate Info

# %%
df_merge_home_away.drop(columns=["country_full_home", "country_full_away"], inplace=True)

# %%
df_merge_home_away
# Out:
#            date  home_team             away_team  home_score  away_score  \
# 0    2018-08-18    Andorra  United Arab Emirates         0.0         0.0
# 1    2018-08-18    Grenada               Jamaica         1.0         5.0
# 2    2018-08-18  Guatemala                  Cuba         1.0         0.0
# 3    2018-08-20   Barbados               Jamaica         2.0         2.0
# 4    2018-08-26   Barbados                  Cuba         0.0         0.0
# ...         ...        ...                   ...         ...         ...
# 3402 2022-09-27     Norway                Serbia         0.0         2.0
# 3403 2022-09-27     Sweden              Slovenia         1.0         1.0
# 3404 2022-09-27     Kosovo                Cyprus         5.0         1.0
# 3405 2022-09-27     Greece      Northern Ireland         3.0         1.0
# 3406 2022-09-30       Fiji       Solomon Islands         1.0         0.0
#
#                     tournament            city    country  neutral  rank_home  \
# ...

# %% [markdown]
# ## Type Conversion

# %%
df_merge_home_away = df_merge_home_away.astype(
    {
        "home_score": int,
        "away_score": int
    }
)

# %%
df_merge_home_away.loc[:, ['date', 'home_team', 'away_team', 'home_score', 'away_score', 'rank_home', 'rank_away']]
# Out:
#            date  home_team             away_team  home_score  away_score  \
# 0    2018-08-18    Andorra  United Arab Emirates           0           0
# 1    2018-08-18    Grenada               Jamaica           1           5
# 2    2018-08-18  Guatemala                  Cuba           1           0
# 3    2018-08-20   Barbados               Jamaica           2           2
# 4    2018-08-26   Barbados                  Cuba           0           0
# ...         ...        ...                   ...         ...         ...
# 3402 2022-09-27     Norway                Serbia           0           2
# 3403 2022-09-27     Sweden              Slovenia           1           1
# 3404 2022-09-27     Kosovo                Cyprus           5           1
# 3405 2022-09-27     Greece      Northern Ireland           3           1
# 3406 2022-09-30       Fiji       Solomon Islands           1           0
#
#       rank_home  rank_away
# 0           130         77
# 1           168         54
# ...

# %% [markdown]
# ## Save

# %%
df_merge_home_away.to_parquet("./intermediate/match_rank.parquet")
